# %% [markdown]
# <a href="https://colab.research.google.com/github/Tyhoover20/sql-challenge/blob/main/SQL_homework_2_3_2025.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
df1 = pd.read_csv('/content/employees.csv')
df2 = pd.read_csv('/content/salaries.csv')
df3 = pd.merge(df1,df2,on='emp_no')
df3
# Out:
#         emp_no emp_title_id  birth_date   first_name  last_name sex  \
# 0       473302        s0001   7/25/1953     Hideyuki   Zallocco   M
# 1       475053        e0002  11/18/1954        Byong  Delgrande   F
# 2        57444        e0002   1/30/1958        Berry       Babb   F
# 3       421786        s0001   9/28/1957        Xiong   Verhoeff   M
# 4       282238        e0003  10/28/1952   Abdelkader    Baumann   F
# ...        ...          ...         ...          ...        ...  ..
# 300019  464231        s0001   8/14/1958  Constantino    Eastman   M
# 300020  255832        e0002    5/8/1955       Yuping     Dayang   F
# 300021   76671        s0001    6/9/1959       Ortrud   Plessier   M
# 300022  264920        s0001   9/22/1959        Percy   Samarati   F
# 300023  464503        s0002   5/31/1964       Arvind  Slobodova   M
#
#          hire_date  salary
# 0        4/28/1990   40000
# 1         9/7/1991   53422
# 2        3/21/1992   48973
# 3       11/26/1987   40000
# ...

# %%
Employee_1986 = df3[df3['hire_date'].str.contains('1986')][['first_name', 'last_name', 'hire_date']]
Employee_1986
# Out:
#        first_name    last_name   hire_date
# 5            Eran     Cusworth  11/14/1986
# 14          Bojan     Zallocco  10/14/1986
# 19          Nevio       Demizu   5/18/1986
# 29           Ziva       Vecchi    7/3/1986
# 33          Mohit        Speek   1/14/1986
# ...           ...          ...         ...
# 299986      Uriel     Heijenga   6/30/1986
# 299998      Ziyad  Constantine   2/28/1986
# 300006     Yishay   Maksimenko   1/27/1986
# 300007     Yannik        Ranai    4/6/1986
# 300017     Chenyi     Orlowska  12/25/1986
#
# [36150 rows x 3 columns]

# %%
#End of questions 1 and 2

# %%
df4 = pd.read_csv('/content/dept_manager.csv')
df5 = pd.read_csv('/content/departments.csv')
df1 = pd.read_csv('/content/employees.csv')
df6 = pd.merge(df4,df5,on='dept_no')
df7 = pd.merge(df6,df1,on='emp_no')
df7
# Out:
#    dept_no  emp_no           dept_name emp_title_id  birth_date   first_name  \
# 0     d001  110022           Marketing        m0001   9/12/1956    Margareta
# 1     d001  110039           Marketing        m0001   6/21/1963     Vishwani
# 2     d002  110085             Finance        m0001  10/28/1959         Ebru
# 3     d002  110114             Finance        m0001   3/28/1957        Isamu
# 4     d003  110183     Human Resources        m0001   6/24/1953      Shirish
# 5     d003  110228     Human Resources        m0001   12/2/1958      Karsten
# 6     d004  110303          Production        m0001    6/8/1956    Krassimir
# 7     d004  110344          Production        m0001    9/7/1961       Rosine
# 8     d004  110386          Production        m0001   10/4/1953         Shem
# 9     d004  110420          Production        m0001   7/27/1963        Oscar
# 10    d005  110511         Development        m0001    7/8/1957     DeForest
# ...

# %%
Manager_Dept = df7[['dept_no','dept_name', 'emp_no','last_name', 'first_name']]
Manager_Dept
# Out:
#    dept_no           dept_name  emp_no     last_name   first_name
# 0     d001           Marketing  110022    Markovitch    Margareta
# 1     d001           Marketing  110039      Minakawa     Vishwani
# 2     d002             Finance  110085         Alpin         Ebru
# 3     d002             Finance  110114    Legleitner        Isamu
# 4     d003     Human Resources  110183  Ossenbruggen      Shirish
# 5     d003     Human Resources  110228       Sigstam      Karsten
# 6     d004          Production  110303       Wegerle    Krassimir
# 7     d004          Production  110344         Cools       Rosine
# 8     d004          Production  110386        Kieras         Shem
# 9     d004          Production  110420      Ghazalie        Oscar
# 10    d005         Development  110511      Hagimont     DeForest
# 11    d005         Development  110567      DasSarma         Leon
# 12    d006  Quality Management  110725       Onuegbe    Peternela
# ...

# %%
#End of question 3

# %%
df8 = pd.read_csv('/content/dept_emp.csv')
df9 = pd.read_csv('/content/departments.csv')
df10 = pd.read_csv('/content/employees.csv')
df11 = pd.merge(df8,df9,on='dept_no')
df12 = pd.merge(df11,df10,on='emp_no')
df12
# Out:
#         emp_no dept_no        dept_name emp_title_id birth_date first_name  \
# 0        10001    d005      Development        e0003   9/2/1953     Georgi
# 1        10002    d007            Sales        s0001   6/2/1964    Bezalel
# 2        10003    d004       Production        e0003  12/3/1959      Parto
# 3        10004    d004       Production        e0003   5/1/1954  Chirstian
# 4        10005    d003  Human Resources        s0001  1/21/1955    Kyoichi
# ...        ...     ...              ...          ...        ...        ...
# 331598  499995    d004       Production        e0002  9/24/1958     Dekang
# 331599  499996    d004       Production        e0003   3/7/1953       Zito
# 331600  499997    d005      Development        e0003   8/3/1961    Berhard
# 331601  499998    d002          Finance        s0001   9/5/1956   Patricia
# 331602  499999    d004       Production        e0002   5/1/1958     Sachin
#
#        last_name sex   hire_date
# 0        Facello   M   6/26/1986
# ...

# %%
df12 = df12[['dept_no','dept_name', 'emp_no','last_name', 'first_name']]
df12
# Out:
#        dept_no        dept_name  emp_no last_name first_name
# 0         d005      Development   10001   Facello     Georgi
# 1         d007            Sales   10002    Simmel    Bezalel
# 2         d004       Production   10003   Bamford      Parto
# 3         d004       Production   10004   Koblick  Chirstian
# 4         d003  Human Resources   10005  Maliniak    Kyoichi
# ...        ...              ...     ...       ...        ...
# 331598    d004       Production  499995  Lichtner     Dekang
# 331599    d004       Production  499996      Baaz       Zito
# 331600    d005      Development  499997    Lenart    Berhard
# 331601    d002          Finance  499998   Breugel   Patricia
# 331602    d004       Production  499999   Tsukuda     Sachin
#
# [331603 rows x 5 columns]

# %%
#end of question 4

# %%
df1 = pd.read_csv('/content/employees.csv')
df1
# Out:
#         emp_no emp_title_id  birth_date   first_name  last_name sex  \
# 0       473302        s0001   7/25/1953     Hideyuki   Zallocco   M
# 1       475053        e0002  11/18/1954        Byong  Delgrande   F
# 2        57444        e0002   1/30/1958        Berry       Babb   F
# 3       421786        s0001   9/28/1957        Xiong   Verhoeff   M
# 4       282238        e0003  10/28/1952   Abdelkader    Baumann   F
# ...        ...          ...         ...          ...        ...  ..
# 300019  464231        s0001   8/14/1958  Constantino    Eastman   M
# 300020  255832        e0002    5/8/1955       Yuping     Dayang   F
# 300021   76671        s0001    6/9/1959       Ortrud   Plessier   M
# 300022  264920        s0001   9/22/1959        Percy   Samarati   F
# 300023  464503        s0002   5/31/1964       Arvind  Slobodova   M
#
#          hire_date
# 0        4/28/1990
# 1         9/7/1991
# 2        3/21/1992
# 3       11/26/1987
# 4        1/18/1991
# ...            ...
# ...

# %%
Hercules_B = Hercules_B[Hercules_B['first_name'].str.contains('Hercules') & df1['last_name'].str.contains('B')]
Hercules_B = Hercules_B[['first_name', 'last_name', 'sex']]
Hercules_B
# Out:
# <ipython-input-72-8a466f5b7be7>:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   Hercules_B = Hercules_B[Hercules_B['first_name'].str.contains('Hercules') & df1['last_name'].str.contains('B')]
#        first_name      last_name sex
# 4218     Hercules           Baer   M
# 15577    Hercules          Biron   F
# 21897    Hercules          Birge   F
# 30877    Hercules        Berstel   F
# 45926    Hercules      Bernatsky   M
# 52269    Hercules           Bail   F
# 66260    Hercules         Bodoff   M
# 66852    Hercules       Benantar   F
# 78130    Hercules        Basagni   M
# 95208    Hercules  Bernardinello   F
# 103674   Hercules     Baranowski   M
# 160668   Hercules        Bisiani   F
# 170814   Hercules     Benzmuller   M
# 180740   Hercules           Bahr   M
# 181147   Hercules          Biran   F
# 209006   Hercules           Bain   F
# 258140   Hercules        Brendel   F
# 261068   Hercules        Buchter   M
# ...

# %%
#End of question 5

# %%
df8 = pd.read_csv('/content/dept_emp.csv')
df9 = pd.read_csv('/content/departments.csv')
df10 = pd.read_csv('/content/employees.csv')
df11 = pd.merge(df8,df9,on='dept_no')
df12 = pd.merge(df11,df10,on='emp_no')
df12
# Out:
#         emp_no dept_no        dept_name emp_title_id birth_date first_name  \
# 0        10001    d005      Development        e0003   9/2/1953     Georgi
# 1        10002    d007            Sales        s0001   6/2/1964    Bezalel
# 2        10003    d004       Production        e0003  12/3/1959      Parto
# 3        10004    d004       Production        e0003   5/1/1954  Chirstian
# 4        10005    d003  Human Resources        s0001  1/21/1955    Kyoichi
# ...        ...     ...              ...          ...        ...        ...
# 331598  499995    d004       Production        e0002  9/24/1958     Dekang
# 331599  499996    d004       Production        e0003   3/7/1953       Zito
# 331600  499997    d005      Development        e0003   8/3/1961    Berhard
# 331601  499998    d002          Finance        s0001   9/5/1956   Patricia
# 331602  499999    d004       Production        e0002   5/1/1958     Sachin
#
#        last_name sex   hire_date
# 0        Facello   M   6/26/1986
# ...

# %%
Sales_Dept = df12[df12['dept_name'].str.contains('Sales')]
Sales_Dept = Sales_Dept[['emp_no','last_name', 'first_name', 'dept_name']]
Sales_Dept
# Out:
#         emp_no    last_name first_name dept_name
# 1        10002       Simmel    Bezalel     Sales
# 16       10016  Cappelletti   Kazuhito     Sales
# 36       10034         Swan      Bader     Sales
# 44       10041       Lenart        Uri     Sales
# 54       10050       Dredge    Yinghua     Sales
# ...        ...          ...        ...       ...
# 331577  499976       Felder   Guozhong     Sales
# 331581  499980        Usery       Gino     Sales
# 331588  499986        Ranta     Nathan     Sales
# 331589  499987       Dusink      Rimli     Sales
# 331590  499988      Kleiser   Bangqing     Sales
#
# [52245 rows x 4 columns]

# %%
#End of question 6

# %%
df12
# Out:
#         emp_no dept_no        dept_name emp_title_id birth_date first_name  \
# 0        10001    d005      Development        e0003   9/2/1953     Georgi
# 1        10002    d007            Sales        s0001   6/2/1964    Bezalel
# 2        10003    d004       Production        e0003  12/3/1959      Parto
# 3        10004    d004       Production        e0003   5/1/1954  Chirstian
# 4        10005    d003  Human Resources        s0001  1/21/1955    Kyoichi
# ...        ...     ...              ...          ...        ...        ...
# 331598  499995    d004       Production        e0002  9/24/1958     Dekang
# 331599  499996    d004       Production        e0003   3/7/1953       Zito
# 331600  499997    d005      Development        e0003   8/3/1961    Berhard
# 331601  499998    d002          Finance        s0001   9/5/1956   Patricia
# 331602  499999    d004       Production        e0002   5/1/1958     Sachin
#
#        last_name sex   hire_date
# 0        Facello   M   6/26/1986
# ...

# %%
Sales_Development = df12[df12['dept_name'].str.contains('Sales') | df12['dept_name'].str.contains('Development')]
Sales_Development = Sales_Development[['emp_no','last_name', 'first_name', 'dept_name']]
Sales_Development
# Out:
#         emp_no  last_name first_name    dept_name
# 0        10001    Facello     Georgi  Development
# 1        10002     Simmel    Bezalel        Sales
# 5        10006    Preusig     Anneke  Development
# 7        10008   Kalloufi     Saniya  Development
# 12       10012  Bridgland   Patricio  Development
# ...        ...        ...        ...          ...
# 331588  499986      Ranta     Nathan        Sales
# 331589  499987     Dusink      Rimli        Sales
# 331590  499988    Kleiser   Bangqing        Sales
# 331592  499990    Kohling     Khaled  Development
# 331600  499997     Lenart    Berhard  Development
#
# [137952 rows x 4 columns]

# %%
df1 = pd.read_csv('/content/employees.csv')
df1
# Out:
#         emp_no emp_title_id  birth_date   first_name  last_name sex  \
# 0       473302        s0001   7/25/1953     Hideyuki   Zallocco   M
# 1       475053        e0002  11/18/1954        Byong  Delgrande   F
# 2        57444        e0002   1/30/1958        Berry       Babb   F
# 3       421786        s0001   9/28/1957        Xiong   Verhoeff   M
# 4       282238        e0003  10/28/1952   Abdelkader    Baumann   F
# ...        ...          ...         ...          ...        ...  ..
# 300019  464231        s0001   8/14/1958  Constantino    Eastman   M
# 300020  255832        e0002    5/8/1955       Yuping     Dayang   F
# 300021   76671        s0001    6/9/1959       Ortrud   Plessier   M
# 300022  264920        s0001   9/22/1959        Percy   Samarati   F
# 300023  464503        s0002   5/31/1964       Arvind  Slobodova   M
#
#          hire_date
# 0        4/28/1990
# 1         9/7/1991
# 2        3/21/1992
# 3       11/26/1987
# 4        1/18/1991
# ...            ...
# ...

# %%
Last_name_count = df1['last_name'].value_counts()
descending_order = Last_name_count.sort_values(ascending=False)
Last_name_count
# Out:
# last_name
# Baba          226
# Coorg         223
# Gelosh        223
# Sudbeck       222
# Farris        222
#              ...
# Georgatos     148
# Guardalben    148
# Merro         147
# Sadowsky      145
# Foolsday        1
# Name: count, Length: 1638, dtype: int64
